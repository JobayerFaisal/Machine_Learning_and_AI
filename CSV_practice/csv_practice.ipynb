# %%
print ("Jobayer Faisal Fahim")
# Out:
# Jobayer Faisal Fahim

# %%
print ('hello')
# Out:
# hello

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('D:/Data_Analysis/Machine_Learning/Machine_Learning_Practice/CSV_practice/test.csv')

# %%
df.head()
# Out:
#     Unnamed: 1 Unnamed: 2              Unnamed: 3 Unnamed: 4  \
# 0  enrollee_id       city  city_development_index     gender
# 1        29725    city_40                   0.776       Male
# 2        11561    city_21                   0.624        NaN
# 3        33241   city_115                   0.789        NaN
# 4          666   city_162                   0.767       Male
#
#                 Unnamed: 5           Unnamed: 6       Unnamed: 7  \
# 0      relevent_experience  enrolled_university  education_level
# 1   No relevent experience        no_enrollment         Graduate
# 2   No relevent experience     Full time course         Graduate
# 3   No relevent experience                  NaN         Graduate
# 4  Has relevent experience        no_enrollment          Masters
#
#          Unnamed: 8  Unnamed: 9   Unnamed: 10     Unnamed: 11   Unnamed: 12  \
# 0  major_discipline  experience  company_size    company_type  last_new_job
# ...

# %%
df.shape
# Out:
# (5, 14)

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#     Unnamed: 1 Unnamed: 2              Unnamed: 3 Unnamed: 4  \
# 0  enrollee_id       city  city_development_index     gender
# 1        29725    city_40                   0.776       Male
# 2        11561    city_21                   0.624        NaN
# 3        33241   city_115                   0.789        NaN
# 4          666   city_162                   0.767       Male
#
#                 Unnamed: 5           Unnamed: 6       Unnamed: 7  \
# 0      relevent_experience  enrolled_university  education_level
# 1   No relevent experience        no_enrollment         Graduate
# 2   No relevent experience     Full time course         Graduate
# 3   No relevent experience                  NaN         Graduate
# 4  Has relevent experience        no_enrollment          Masters
#
#          Unnamed: 8  Unnamed: 9   Unnamed: 10     Unnamed: 11   Unnamed: 12  \
# 0  major_discipline  experience  company_size    company_type  last_new_job
# ...

# %%
df.shape
# Out:
# (5, 14)

# %% [markdown]
# df.info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 1   5 non-null      object
#  1   Unnamed: 2   5 non-null      object
#  2   Unnamed: 3   5 non-null      object
#  3   Unnamed: 4   3 non-null      object
#  4   Unnamed: 5   5 non-null      object
#  5   Unnamed: 6   4 non-null      object
#  6   Unnamed: 7   5 non-null      object
#  7   Unnamed: 8   5 non-null      object
#  8   Unnamed: 9   5 non-null      object
#  9   Unnamed: 10  3 non-null      object
#  10  Unnamed: 11  4 non-null      object
#  11  Unnamed: 12  5 non-null      object
#  12  Unnamed: 13  5 non-null      object
#  13  Unnamed: 14  5 non-null      object
# dtypes: object(14)
# memory usage: 692.0+ bytes

# %%
df.head()
# Out:
#     Unnamed: 1 Unnamed: 2              Unnamed: 3 Unnamed: 4  \
# 0  enrollee_id       city  city_development_index     gender
# 1        29725    city_40                   0.776       Male
# 2        11561    city_21                   0.624        NaN
# 3        33241   city_115                   0.789        NaN
# 4          666   city_162                   0.767       Male
#
#                 Unnamed: 5           Unnamed: 6       Unnamed: 7  \
# 0      relevent_experience  enrolled_university  education_level
# 1   No relevent experience        no_enrollment         Graduate
# 2   No relevent experience     Full time course         Graduate
# 3   No relevent experience                  NaN         Graduate
# 4  Has relevent experience        no_enrollment          Masters
#
#          Unnamed: 8  Unnamed: 9   Unnamed: 10     Unnamed: 11   Unnamed: 12  \
# 0  major_discipline  experience  company_size    company_type  last_new_job
# ...

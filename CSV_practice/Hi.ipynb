# %%
print ("Jobayer Faisal Fahim")
# Out:
# Jobayer Faisal Fahim

# %%
print ("Dina")
# Out:
# Dina

# %%
import tensorflow as tf
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import tensorflow as tf
#       2 print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import torch
#       2 print(torch.cuda.is_available())
#       3 print(torch.cuda.get_device_name(0))
#
# File c:\Users\USER\.conda\envs\gpuenv\lib\site-packages\torch\__init__.py:274
#     270                     raise err
#     272         kernel32.SetErrorMode(prev_error_mode)
# --> 274     _load_dll_libraries()
#     275     del _load_dll_libraries
#     278 def _preload_cuda_deps(lib_folder: str, lib_name: str) -> None:
#
# File c:\Users\USER\.conda\envs\gpuenv\lib\site-packages\torch\__init__.py:257, in _load_dll_libraries()
#     253     err = ctypes.WinError(last_error)
#     254     err.strerror += (
#     255         f' Error loading "{dll}" or one of its dependencies.'
#     256     )
# --> 257     raise err
#     258 elif res is not None:
#     259     is_loaded = True
#
# OSError: [WinError 193] %1 is not a valid Win32 application. Error loading "c:\Users\USER\.conda\envs\gpuenv\lib\site-packages\torch\lib\shm.dll" or one of its dependencies.
